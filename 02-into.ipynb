# %% [markdown]
# <img src="images/continuum_analytics_logo.png"
#                                 alt="Continuum Logo",
#                                 align="right",
#                                 width="30%">,
#
# `into`
# ======
#
# Into migrates data between formats and locations.
#
# Before we can use a database we need to move data into it.  The `into` project provides a single consistent interface to move data between formats and between locations.
#
# We'll start with local data and eventually move out to remote data.
#
# [*into docs*](http://into.readthedocs.org/en/latest/index.html)

# %% [markdown]
# ### Examples
#
#
# Into moves data into a target from a source
#
# ```
# >>> into(target, source)
# ```
#
# The target and source can be either a Python object or a string URI.  The following are all valid calls to `into`
#
# ```
# >>> into(pd.DataFrame, 'iris.csv')  # Load CSV file into new DataFrame
# >>> into('iris.json', my_df)        # Write DataFrame into JSON file
# >>> into('iris.json', 'iris.csv')   # Migrate data from CSV to JSON
# ```

# %% [markdown]
# ### Excerise
#
# Use `into` to load the `iris.csv` file into a Python `list`, a `np.ndarray`, and a `pd.DataFrame`

# %%
from into import into
import numpy as np
import pandas as pd

into(np.ndarray, 'iris.csv')
# Out:
# rec.array([(5.1, 3.5, 1.4, 0.2, u'Iris-setosa'),
#        (4.9, 3.0, 1.4, 0.2, u'Iris-setosa'),
#        (4.7, 3.2, 1.3, 0.2, u'Iris-setosa'),
#        (4.6, 3.1, 1.5, 0.2, u'Iris-setosa'),
#        (5.0, 3.6, 1.4, 0.2, u'Iris-setosa'),
#        (5.4, 3.9, 1.7, 0.4, u'Iris-setosa'),
#        (4.6, 3.4, 1.4, 0.3, u'Iris-setosa'),
#        (5.0, 3.4, 1.5, 0.2, u'Iris-setosa'),
#        (4.4, 2.9, 1.4, 0.2, u'Iris-setosa'),
#        (4.9, 3.1, 1.5, 0.1, u'Iris-setosa'),
#        (5.4, 3.7, 1.5, 0.2, u'Iris-setosa'),
#        (4.8, 3.4, 1.6, 0.2, u'Iris-setosa'),
#        (4.8, 3.0, 1.4, 0.1, u'Iris-setosa'),
#        (4.3, 3.0, 1.1, 0.1, u'Iris-setosa'),
#        (5.8, 4.0, 1.2, 0.2, u'Iris-setosa'),
#        (5.7, 4.4, 1.5, 0.4, u'Iris-setosa'),
#        (5.4, 3.9, 1.3, 0.4, u'Iris-setosa'),
#        (5.1, 3.5, 1.4, 0.3, u'Iris-setosa'),
#        (5.7, 3.8, 1.7, 0.3, u'Iris-setosa'),
#        (5.1, 3.8, 1.5, 0.3, u'Iris-setosa'),
#        (5.4, 3.4, 1.7, 0.2, u'Iris-setosa'),
#        (5.1, 3.7, 1.5, 0.4, u'Iris-setosa'),
#        (4.6, 3.6, 1.0, 0.2, u'Iris-setosa'),
#        (5.1, 3.3, 1.7, 0.5, u'Iris-setosa'),
#        (4.8, 3.4, 1.9, 0.2, u'Iris-setosa'),
#        (5.0, 3.0, 1.6, 0.2, u'Iris-setosa'),
#        (5.0, 3.4, 1.6, 0.4, u'Iris-setosa'),
#        (5.2, 3.5, 1.5, 0.2, u'Iris-setosa'),
#        (5.2, 3.4, 1.4, 0.2, u'Iris-setosa'),
#        (4.7, 3.2, 1.6, 0.2, u'Iris-setosa'),
#        (4.8, 3.1, 1.6, 0.2, u'Iris-setosa'),
#        (5.4, 3.4, 1.5, 0.4, u'Iris-setosa'),
#        (5.2, 4.1, 1.5, 0.1, u'Iris-setosa'),
#        (5.5, 4.2, 1.4, 0.2, u'Iris-setosa'),
#        (4.9, 3.1, 1.5, 0.2, u'Iris-setosa'),
#        (5.0, 3.2, 1.2, 0.2, u'Iris-setosa'),
#        (5.5, 3.5, 1.3, 0.2, u'Iris-setosa'),
#        (4.9, 3.6, 1.4, 0.1, u'Iris-setosa'),
#        (4.4, 3.0, 1.3, 0.2, u'Iris-setosa'),
#        (5.1, 3.4, 1.5, 0.2, u'Iris-setosa'),
#        (5.0, 3.5, 1.3, 0.3, u'Iris-setosa'),
#        (4.5, 2.3, 1.3, 0.3, u'Iris-setosa'),
#        (4.4, 3.2, 1.3, 0.2, u'Iris-setosa'),
#        (5.0, 3.5, 1.6, 0.6, u'Iris-setosa'),
#        (5.1, 3.8, 1.9, 0.4, u'Iris-setosa'),
#        (4.8, 3.0, 1.4, 0.3, u'Iris-setosa'),
#        (5.1, 3.8, 1.6, 0.2, u'Iris-setosa'),
#        (4.6, 3.2, 1.4, 0.2, u'Iris-setosa'),
#        (5.3, 3.7, 1.5, 0.2, u'Iris-setosa'),
#        (5.0, 3.3, 1.4, 0.2, u'Iris-setosa'),
#        (7.0, 3.2, 4.7, 1.4, u'Iris-versicolor'),
#        (6.4, 3.2, 4.5, 1.5, u'Iris-versicolor'),
#        (6.9, 3.1, 4.9, 1.5, u'Iris-versicolor'),
#        (5.5, 2.3, 4.0, 1.3, u'Iris-versicolor'),
#        (6.5, 2.8, 4.6, 1.5, u'Iris-versicolor'),
#        (5.7, 2.8, 4.5, 1.3, u'Iris-versicolor'),
#        (6.3, 3.3, 4.7, 1.6, u'Iris-versicolor'),
#        (4.9, 2.4, 3.3, 1.0, u'Iris-versicolor'),
#        (6.6, 2.9, 4.6, 1.3, u'Iris-versicolor'),
#        (5.2, 2.7, 3.9, 1.4, u'Iris-versicolor'),
#        (5.0, 2.0, 3.5, 1.0, u'Iris-versicolor'),
#        (5.9, 3.0, 4.2, 1.5, u'Iris-versicolor'),
#        (6.0, 2.2, 4.0, 1.0, u'Iris-versicolor'),
#        (6.1, 2.9, 4.7, 1.4, u'Iris-versicolor'),
#        (5.6, 2.9, 3.6, 1.3, u'Iris-versicolor'),
#        (6.7, 3.1, 4.4, 1.4, u'Iris-versicolor'),
#        (5.6, 3.0, 4.5, 1.5, u'Iris-versicolor'),
#        (5.8, 2.7, 4.1, 1.0, u'Iris-versicolor'),
#        (6.2, 2.2, 4.5, 1.5, u'Iris-versicolor'),
#        (5.6, 2.5, 3.9, 1.1, u'Iris-versicolor'),
#        (5.9, 3.2, 4.8, 1.8, u'Iris-versicolor'),
#        (6.1, 2.8, 4.0, 1.3, u'Iris-versicolor'),
#        (6.3, 2.5, 4.9, 1.5, u'Iris-versicolor'),
#        (6.1, 2.8, 4.7, 1.2, u'Iris-versicolor'),
#        (6.4, 2.9, 4.3, 1.3, u'Iris-versicolor'),
#        (6.6, 3.0, 4.4, 1.4, u'Iris-versicolor'),
#        (6.8, 2.8, 4.8, 1.4, u'Iris-versicolor'),
#        (6.7, 3.0, 5.0, 1.7, u'Iris-versicolor'),
#        (6.0, 2.9, 4.5, 1.5, u'Iris-versicolor'),
#        (5.7, 2.6, 3.5, 1.0, u'Iris-versicolor'),
#        (5.5, 2.4, 3.8, 1.1, u'Iris-versicolor'),
#        (5.5, 2.4, 3.7, 1.0, u'Iris-versicolor'),
#        (5.8, 2.7, 3.9, 1.2, u'Iris-versicolor'),
#        (6.0, 2.7, 5.1, 1.6, u'Iris-versicolor'),
#        (5.4, 3.0, 4.5, 1.5, u'Iris-versicolor'),
#        (6.0, 3.4, 4.5, 1.6, u'Iris-versicolor'),
#        (6.7, 3.1, 4.7, 1.5, u'Iris-versicolor'),
#        (6.3, 2.3, 4.4, 1.3, u'Iris-versicolor'),
#        (5.6, 3.0, 4.1, 1.3, u'Iris-versicolor'),
#        (5.5, 2.5, 4.0, 1.3, u'Iris-versicolor'),
#        (5.5, 2.6, 4.4, 1.2, u'Iris-versicolor'),
#        (6.1, 3.0, 4.6, 1.4, u'Iris-versicolor'),
#        (5.8, 2.6, 4.0, 1.2, u'Iris-versicolor'),
#        (5.0, 2.3, 3.3, 1.0, u'Iris-versicolor'),
#        (5.6, 2.7, 4.2, 1.3, u'Iris-versicolor'),
#        (5.7, 3.0, 4.2, 1.2, u'Iris-versicolor'),
#        (5.7, 2.9, 4.2, 1.3, u'Iris-versicolor'),
#        (6.2, 2.9, 4.3, 1.3, u'Iris-versicolor'),
#        (5.1, 2.5, 3.0, 1.1, u'Iris-versicolor'),
#        (5.7, 2.8, 4.1, 1.3, u'Iris-versicolor'),
#        (6.3, 3.3, 6.0, 2.5, u'Iris-virginica'),
#        (5.8, 2.7, 5.1, 1.9, u'Iris-virginica'),
#        (7.1, 3.0, 5.9, 2.1, u'Iris-virginica'),
#        (6.3, 2.9, 5.6, 1.8, u'Iris-virginica'),
#        (6.5, 3.0, 5.8, 2.2, u'Iris-virginica'),
#        (7.6, 3.0, 6.6, 2.1, u'Iris-virginica'),
#        (4.9, 2.5, 4.5, 1.7, u'Iris-virginica'),
#        (7.3, 2.9, 6.3, 1.8, u'Iris-virginica'),
#        (6.7, 2.5, 5.8, 1.8, u'Iris-virginica'),
#        (7.2, 3.6, 6.1, 2.5, u'Iris-virginica'),
#        (6.5, 3.2, 5.1, 2.0, u'Iris-virginica'),
#        (6.4, 2.7, 5.3, 1.9, u'Iris-virginica'),
#        (6.8, 3.0, 5.5, 2.1, u'Iris-virginica'),
#        (5.7, 2.5, 5.0, 2.0, u'Iris-virginica'),
#        (5.8, 2.8, 5.1, 2.4, u'Iris-virginica'),
#        (6.4, 3.2, 5.3, 2.3, u'Iris-virginica'),
#        (6.5, 3.0, 5.5, 1.8, u'Iris-virginica'),
#        (7.7, 3.8, 6.7, 2.2, u'Iris-virginica'),
#        (7.7, 2.6, 6.9, 2.3, u'Iris-virginica'),
#        (6.0, 2.2, 5.0, 1.5, u'Iris-virginica'),
#        (6.9, 3.2, 5.7, 2.3, u'Iris-virginica'),
#        (5.6, 2.8, 4.9, 2.0, u'Iris-virginica'),
#        (7.7, 2.8, 6.7, 2.0, u'Iris-virginica'),
#        (6.3, 2.7, 4.9, 1.8, u'Iris-virginica'),
#        (6.7, 3.3, 5.7, 2.1, u'Iris-virginica'),
#        (7.2, 3.2, 6.0, 1.8, u'Iris-virginica'),
#        (6.2, 2.8, 4.8, 1.8, u'Iris-virginica'),
#        (6.1, 3.0, 4.9, 1.8, u'Iris-virginica'),
#        (6.4, 2.8, 5.6, 2.1, u'Iris-virginica'),
#        (7.2, 3.0, 5.8, 1.6, u'Iris-virginica'),
#        (7.4, 2.8, 6.1, 1.9, u'Iris-virginica'),
#        (7.9, 3.8, 6.4, 2.0, u'Iris-virginica'),
#        (6.4, 2.8, 5.6, 2.2, u'Iris-virginica'),
#        (6.3, 2.8, 5.1, 1.5, u'Iris-virginica'),
#        (6.1, 2.6, 5.6, 1.4, u'Iris-virginica'),
#        (7.7, 3.0, 6.1, 2.3, u'Iris-virginica'),
#        (6.3, 3.4, 5.6, 2.4, u'Iris-virginica'),
#        (6.4, 3.1, 5.5, 1.8, u'Iris-virginica'),
#        (6.0, 3.0, 4.8, 1.8, u'Iris-virginica'),
#        (6.9, 3.1, 5.4, 2.1, u'Iris-virginica'),
#        (6.7, 3.1, 5.6, 2.4, u'Iris-virginica'),
#        (6.9, 3.1, 5.1, 2.3, u'Iris-virginica'),
#        (5.8, 2.7, 5.1, 1.9, u'Iris-virginica'),
#        (6.8, 3.2, 5.9, 2.3, u'Iris-virginica'),
#        (6.7, 3.3, 5.7, 2.5, u'Iris-virginica'),
#        (6.7, 3.0, 5.2, 2.3, u'Iris-virginica'),
#        (6.3, 2.5, 5.0, 1.9, u'Iris-virginica'),
#        (6.5, 3.0, 5.2, 2.0, u'Iris-virginica'),
#        (6.2, 3.4, 5.4, 2.3, u'Iris-virginica'),
#        (5.9, 3.0, 5.1, 1.8, u'Iris-virginica')],
#       dtype=[('sepal_length', '<f8'), ('sepal_width', '<f8'), ('petal_length', '<f8'), ('petal_width', '<f8'), ('species', 'O')])

# %% [markdown]
# URI Strings
# -----------
#
# Into refers to foreign data either with a Python object like a `sqlalchemy.Table` object for a SQL table, or with a string URI, like `postgresql://hostname::tablename`.
#
# URI's often take on the following form
#
#     protocol://path-to-resource::path-within-resource
#
# Where `path-to-resource` might point to a file, a database hostname, etc. while `path-within-resource` might refer to a datapath or table name.  Note the two main separators
#
# *   `://` separates the protocol on the left (`sqlite`, `mongodb`, `ssh`, `hdfs`, `hive`, ...)
# *   `::` separates the path within the database on the right (e.g. tablename)
#
# [*into docs on uri strings*](http://into.readthedocs.org/en/latest/uri.html)

# %% [markdown]
# ### Examples
#
# Here are some example URIs
#
#     myfile.json
#     myfiles.*.csv'
#     postgresql://hostname::tablename
#     mongodb://hostname/db::collection
#     ssh://user@host:/path/to/myfile.csv
#     hdfs://user@host:/path/to/*.csv

# %% [markdown]
# ### Exercise
#
# Migrate your CSV file into a table named `iris` in a new SQLite database at `sqlite:///my.db`.  Remember to use the `::` separator and to separate your database name from your table name.
#
# [*into docs on SQL*](http://into.readthedocs.org/en/latest/sql.html)

# %%
t = into('sqlite:///my.db::iris', 'iris.csv')
t
# Out:
# Table('iris', MetaData(bind=Engine(sqlite:///my.db)), Column('sepal_length', Float(precision=53), table=<iris>), Column('sepal_width', Float(precision=53), table=<iris>), Column('petal_length', Float(precision=53), table=<iris>), Column('petal_width', Float(precision=53), table=<iris>), Column('species', Text(), table=<iris>), schema=None)

# %% [markdown]
# What kind of object did you get receive as output?  Call `type` on your result.

# %%
type(t)
# Out:
# sqlalchemy.sql.schema.Table

# %% [markdown]
# ### Exercise
#
# We have a MongoDB database waiting for you at the following address
#
#     mongodb://ec2-54-159-160-163.compute-1.amazonaws.com/db
#
# Move your newly built SQLite table into a MongoDB collection.  Remember to use `::` to add a name to your collection.

# %%
c = into('mongodb://ec2-54-159-160-163.compute-1.amazonaws.com/db::iris', 'sqlite:///my.db::iris')
c
# Out:
# Collection(Database(MongoClient('ec2-54-159-160-163.compute-1.amazonaws.com', 27017), u'db'), u'iris')

# %% [markdown]
# Verify that your data arrived safely by converting your mongo collection into a list.

# %%
into(list, c)
# Out:
# [(1.4, 0.2, 5.1, 3.5, u'Iris-setosa'),
#  (1.4, 0.2, 4.9, 3.0, u'Iris-setosa'),
#  (1.3, 0.2, 4.7, 3.2, u'Iris-setosa'),
#  (1.5, 0.2, 4.6, 3.1, u'Iris-setosa'),
#  (1.4, 0.2, 5.0, 3.6, u'Iris-setosa'),
#  (1.7, 0.4, 5.4, 3.9, u'Iris-setosa'),
#  (1.4, 0.3, 4.6, 3.4, u'Iris-setosa'),
#  (1.5, 0.2, 5.0, 3.4, u'Iris-setosa'),
#  (1.4, 0.2, 4.4, 2.9, u'Iris-setosa'),
#  (1.5, 0.1, 4.9, 3.1, u'Iris-setosa'),
#  (1.5, 0.2, 5.4, 3.7, u'Iris-setosa'),
#  (1.6, 0.2, 4.8, 3.4, u'Iris-setosa'),
#  (1.4, 0.1, 4.8, 3.0, u'Iris-setosa'),
#  (1.1, 0.1, 4.3, 3.0, u'Iris-setosa'),
#  (1.2, 0.2, 5.8, 4.0, u'Iris-setosa'),
#  (1.5, 0.4, 5.7, 4.4, u'Iris-setosa'),
#  (1.3, 0.4, 5.4, 3.9, u'Iris-setosa'),
#  (1.4, 0.3, 5.1, 3.5, u'Iris-setosa'),
#  (1.7, 0.3, 5.7, 3.8, u'Iris-setosa'),
#  (1.5, 0.3, 5.1, 3.8, u'Iris-setosa'),
#  (1.7, 0.2, 5.4, 3.4, u'Iris-setosa'),
#  (1.5, 0.4, 5.1, 3.7, u'Iris-setosa'),
#  (1.0, 0.2, 4.6, 3.6, u'Iris-setosa'),
#  (1.7, 0.5, 5.1, 3.3, u'Iris-setosa'),
#  (1.9, 0.2, 4.8, 3.4, u'Iris-setosa'),
#  (1.6, 0.2, 5.0, 3.0, u'Iris-setosa'),
#  (1.6, 0.4, 5.0, 3.4, u'Iris-setosa'),
#  (1.5, 0.2, 5.2, 3.5, u'Iris-setosa'),
#  (1.4, 0.2, 5.2, 3.4, u'Iris-setosa'),
#  (1.6, 0.2, 4.7, 3.2, u'Iris-setosa'),
#  (1.6, 0.2, 4.8, 3.1, u'Iris-setosa'),
#  (1.5, 0.4, 5.4, 3.4, u'Iris-setosa'),
#  (1.5, 0.1, 5.2, 4.1, u'Iris-setosa'),
#  (1.4, 0.2, 5.5, 4.2, u'Iris-setosa'),
#  (1.5, 0.2, 4.9, 3.1, u'Iris-setosa'),
#  (1.2, 0.2, 5.0, 3.2, u'Iris-setosa'),
#  (1.3, 0.2, 5.5, 3.5, u'Iris-setosa'),
#  (1.4, 0.1, 4.9, 3.6, u'Iris-setosa'),
#  (1.3, 0.2, 4.4, 3.0, u'Iris-setosa'),
#  (1.5, 0.2, 5.1, 3.4, u'Iris-setosa'),
#  (1.3, 0.3, 5.0, 3.5, u'Iris-setosa'),
#  (1.3, 0.3, 4.5, 2.3, u'Iris-setosa'),
#  (1.3, 0.2, 4.4, 3.2, u'Iris-setosa'),
#  (1.6, 0.6, 5.0, 3.5, u'Iris-setosa'),
#  (1.9, 0.4, 5.1, 3.8, u'Iris-setosa'),
#  (1.4, 0.3, 4.8, 3.0, u'Iris-setosa'),
#  (1.6, 0.2, 5.1, 3.8, u'Iris-setosa'),
#  (1.4, 0.2, 4.6, 3.2, u'Iris-setosa'),
#  (1.5, 0.2, 5.3, 3.7, u'Iris-setosa'),
#  (1.4, 0.2, 5.0, 3.3, u'Iris-setosa'),
#  (4.7, 1.4, 7.0, 3.2, u'Iris-versicolor'),
#  (4.5, 1.5, 6.4, 3.2, u'Iris-versicolor'),
#  (4.9, 1.5, 6.9, 3.1, u'Iris-versicolor'),
#  (4.0, 1.3, 5.5, 2.3, u'Iris-versicolor'),
#  (4.6, 1.5, 6.5, 2.8, u'Iris-versicolor'),
#  (4.5, 1.3, 5.7, 2.8, u'Iris-versicolor'),
#  (4.7, 1.6, 6.3, 3.3, u'Iris-versicolor'),
#  (3.3, 1.0, 4.9, 2.4, u'Iris-versicolor'),
#  (4.6, 1.3, 6.6, 2.9, u'Iris-versicolor'),
#  (3.9, 1.4, 5.2, 2.7, u'Iris-versicolor'),
#  (3.5, 1.0, 5.0, 2.0, u'Iris-versicolor'),
#  (4.2, 1.5, 5.9, 3.0, u'Iris-versicolor'),
#  (4.0, 1.0, 6.0, 2.2, u'Iris-versicolor'),
#  (4.7, 1.4, 6.1, 2.9, u'Iris-versicolor'),
#  (3.6, 1.3, 5.6, 2.9, u'Iris-versicolor'),
#  (4.4, 1.4, 6.7, 3.1, u'Iris-versicolor'),
#  (4.5, 1.5, 5.6, 3.0, u'Iris-versicolor'),
#  (4.1, 1.0, 5.8, 2.7, u'Iris-versicolor'),
#  (4.5, 1.5, 6.2, 2.2, u'Iris-versicolor'),
#  (3.9, 1.1, 5.6, 2.5, u'Iris-versicolor'),
#  (4.8, 1.8, 5.9, 3.2, u'Iris-versicolor'),
#  (4.0, 1.3, 6.1, 2.8, u'Iris-versicolor'),
#  (4.9, 1.5, 6.3, 2.5, u'Iris-versicolor'),
#  (4.7, 1.2, 6.1, 2.8, u'Iris-versicolor'),
#  (4.3, 1.3, 6.4, 2.9, u'Iris-versicolor'),
#  (4.4, 1.4, 6.6, 3.0, u'Iris-versicolor'),
#  (4.8, 1.4, 6.8, 2.8, u'Iris-versicolor'),
#  (5.0, 1.7, 6.7, 3.0, u'Iris-versicolor'),
#  (4.5, 1.5, 6.0, 2.9, u'Iris-versicolor'),
#  (3.5, 1.0, 5.7, 2.6, u'Iris-versicolor'),
#  (3.8, 1.1, 5.5, 2.4, u'Iris-versicolor'),
#  (3.7, 1.0, 5.5, 2.4, u'Iris-versicolor'),
#  (3.9, 1.2, 5.8, 2.7, u'Iris-versicolor'),
#  (5.1, 1.6, 6.0, 2.7, u'Iris-versicolor'),
#  (4.5, 1.5, 5.4, 3.0, u'Iris-versicolor'),
#  (4.5, 1.6, 6.0, 3.4, u'Iris-versicolor'),
#  (4.7, 1.5, 6.7, 3.1, u'Iris-versicolor'),
#  (4.4, 1.3, 6.3, 2.3, u'Iris-versicolor'),
#  (4.1, 1.3, 5.6, 3.0, u'Iris-versicolor'),
#  (4.0, 1.3, 5.5, 2.5, u'Iris-versicolor'),
#  (4.4, 1.2, 5.5, 2.6, u'Iris-versicolor'),
#  (4.6, 1.4, 6.1, 3.0, u'Iris-versicolor'),
#  (4.0, 1.2, 5.8, 2.6, u'Iris-versicolor'),
#  (3.3, 1.0, 5.0, 2.3, u'Iris-versicolor'),
#  (4.2, 1.3, 5.6, 2.7, u'Iris-versicolor'),
#  (4.2, 1.2, 5.7, 3.0, u'Iris-versicolor'),
#  (4.2, 1.3, 5.7, 2.9, u'Iris-versicolor'),
#  (4.3, 1.3, 6.2, 2.9, u'Iris-versicolor'),
#  (3.0, 1.1, 5.1, 2.5, u'Iris-versicolor'),
#  (4.1, 1.3, 5.7, 2.8, u'Iris-versicolor'),
#  (6.0, 2.5, 6.3, 3.3, u'Iris-virginica'),
#  (5.1, 1.9, 5.8, 2.7, u'Iris-virginica'),
#  (5.9, 2.1, 7.1, 3.0, u'Iris-virginica'),
#  (5.6, 1.8, 6.3, 2.9, u'Iris-virginica'),
#  (5.8, 2.2, 6.5, 3.0, u'Iris-virginica'),
#  (6.6, 2.1, 7.6, 3.0, u'Iris-virginica'),
#  (4.5, 1.7, 4.9, 2.5, u'Iris-virginica'),
#  (6.3, 1.8, 7.3, 2.9, u'Iris-virginica'),
#  (5.8, 1.8, 6.7, 2.5, u'Iris-virginica'),
#  (6.1, 2.5, 7.2, 3.6, u'Iris-virginica'),
#  (5.1, 2.0, 6.5, 3.2, u'Iris-virginica'),
#  (5.3, 1.9, 6.4, 2.7, u'Iris-virginica'),
#  (5.5, 2.1, 6.8, 3.0, u'Iris-virginica'),
#  (5.0, 2.0, 5.7, 2.5, u'Iris-virginica'),
#  (5.1, 2.4, 5.8, 2.8, u'Iris-virginica'),
#  (5.3, 2.3, 6.4, 3.2, u'Iris-virginica'),
#  (5.5, 1.8, 6.5, 3.0, u'Iris-virginica'),
#  (6.7, 2.2, 7.7, 3.8, u'Iris-virginica'),
#  (6.9, 2.3, 7.7, 2.6, u'Iris-virginica'),
#  (5.0, 1.5, 6.0, 2.2, u'Iris-virginica'),
#  (5.7, 2.3, 6.9, 3.2, u'Iris-virginica'),
#  (4.9, 2.0, 5.6, 2.8, u'Iris-virginica'),
#  (6.7, 2.0, 7.7, 2.8, u'Iris-virginica'),
#  (4.9, 1.8, 6.3, 2.7, u'Iris-virginica'),
#  (5.7, 2.1, 6.7, 3.3, u'Iris-virginica'),
#  (6.0, 1.8, 7.2, 3.2, u'Iris-virginica'),
#  (4.8, 1.8, 6.2, 2.8, u'Iris-virginica'),
#  (4.9, 1.8, 6.1, 3.0, u'Iris-virginica'),
#  (5.6, 2.1, 6.4, 2.8, u'Iris-virginica'),
#  (5.8, 1.6, 7.2, 3.0, u'Iris-virginica'),
#  (6.1, 1.9, 7.4, 2.8, u'Iris-virginica'),
#  (6.4, 2.0, 7.9, 3.8, u'Iris-virginica'),
#  (5.6, 2.2, 6.4, 2.8, u'Iris-virginica'),
#  (5.1, 1.5, 6.3, 2.8, u'Iris-virginica'),
#  (5.6, 1.4, 6.1, 2.6, u'Iris-virginica'),
#  (6.1, 2.3, 7.7, 3.0, u'Iris-virginica'),
#  (5.6, 2.4, 6.3, 3.4, u'Iris-virginica'),
#  (5.5, 1.8, 6.4, 3.1, u'Iris-virginica'),
#  (4.8, 1.8, 6.0, 3.0, u'Iris-virginica'),
#  (5.4, 2.1, 6.9, 3.1, u'Iris-virginica'),
#  (5.6, 2.4, 6.7, 3.1, u'Iris-virginica'),
#  (5.1, 2.3, 6.9, 3.1, u'Iris-virginica'),
#  (5.1, 1.9, 5.8, 2.7, u'Iris-virginica'),
#  (5.9, 2.3, 6.8, 3.2, u'Iris-virginica'),
#  (5.7, 2.5, 6.7, 3.3, u'Iris-virginica'),
#  (5.2, 2.3, 6.7, 3.0, u'Iris-virginica'),
#  (5.0, 1.9, 6.3, 2.5, u'Iris-virginica'),
#  (5.2, 2.0, 6.5, 3.0, u'Iris-virginica'),
#  (5.4, 2.3, 6.2, 3.4, u'Iris-virginica'),
#  (5.1, 1.8, 5.9, 3.0, u'Iris-virginica')]

# %% [markdown]
# Finally, clearn up and remove your collection from the MongoDB by calling the `drop` function.

# %%
from into import drop

drop('mongodb://ec2-54-159-160-163.compute-1.amazonaws.com/db::iris')

# %% [markdown]
# How it works
# ------------
#
# Into is a network of fast pairwise conversions between pairs of formats.  We when we migrate between two formats we traverse a path of pairwise conversions.
#
# We visualize that network below:
#
# ![](images/conversions.png)
#
# Each node represents a data format. Each directed edge represents a function to transform data between two formats. A single call to into may traverse multiple edges and multiple intermediate formats. Red nodes support larger-than-memory data.

# %% [markdown]
# ### Example Path
#
# A single call to into may traverse several intermediate formats calling on several conversion functions.   For example, we when migrate a CSV file to a Mongo database we might take the following route:
#
# * Load in to a `DataFrame` (`pandas.read_csv`)
# * Convert to `np.recarray` (`DataFrame.to_records`)
# * Then to a Python `Iterator` (`np.ndarray.tolist`)
# * Finally to Mongo (`pymongo.Collection.insert`)
#
# Alternatively we could write a special function that uses MongoDB's native CSV
# loader and shortcut this entire process with a direct edge `CSV -> Mongo`.
#
# These functions are chosen because they are fast, often far faster than converting through a central serialization format.
#
# This picture is actually from an older version of `into`, when the graph was still small enough to visualize pleasantly.  See [*into docs*](http://into.readthedocs.org/en/latest/overview.html) for a more updated version.

# %% [markdown]
# Remote Data
# -----------
#
# We can interact with remote data in three locations
#
# 1.  On Amazon's S3 (this will be quick)
# 2.  On a remote machine via `ssh`
# 3.  On the Hadoop File System (HDFS)
#
# For most of this we'll wait until we've seen Blaze, briefly we'll use S3.

# %% [markdown]
# ### S3
#
# For now, we quickly grab a file from Amazon's `S3`.
#
# This example depends on  [`boto`](https://boto.readthedocs.org/en/latest/) to interact with S3.
#
#     conda install boto
#
# [*into docs on aws*](http://into.readthedocs.org/en/latest/aws.html)

# %%
into(pd.DataFrame, 's3://nyqpug/tips.csv')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
